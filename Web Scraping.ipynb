# %% [markdown]
# ## Web Scraping

# %%
#BeautifulSoup and Requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.scrapethissite.com/pages/forms/'

# %%
#checks if server is available
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
# find and find all

# %%
soup.find('div')
# Out:
# <h1>
#                             Hockey Teams: Forms, Searching and Pagination
#                             <small>25 items</small>
# </h1>

# %%
#selecting a particular tag
soup.find_all('p',class_ = 'lead')
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>]

# %%
#selecting a particular tag text
soup.find('p',class_ = 'lead').text.strip()
# Out:
# 'Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.'

# %%
soup.find_all('th')
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
soup.find('th').text.strip()
# Out:
# 'Team Name'

# %% [markdown]
# ## Scraping Data from Real Website + Pandas

# %% [markdown]
# ## ViztaEdu

# %%
from bs4 import BeautifulSoup
import requests

# %%
urls= 'https://viztaedu.com/'

# %%
pages = requests.get(urls)

# %%
soups= BeautifulSoup(pages.text,'html')

# %%
soups.find_all('figcaption')[1]
# Out:
# <figcaption class="wp-caption-text gallery-caption" id="gallery-1-3124">
# 				Career Seminar for GHABSA-UCC
# 				</figcaption>

# %%
soups.find('figcaption', id="gallery-1-3124").text.strip()
# Out:
# 'Career Seminar for GHABSA-UCC'

# %%
"Event" +" - " + soups.find('figcaption', id="gallery-1-3124").text.strip()
# Out:
# 'Event - Career Seminar for GHABSA-UCC'

# %%
urlss= 'https://finance.yahoo.com/trending-tickers'

# %%
pagess = requests.get(urlss)

# %%
pagess
# Out:
# <Response [200]>

# %%
soupsss= BeautifulSoup(pagess.text,'html')

# %%
table_head = soupsss.find_all('th')

# %%
table_head_fm = [ title.text.strip() for  title in table_head]
table_head_fm
# Out:
# ['Symbol',
#  'Name',
#  'Last Price',
#  'Market Time',
#  'Change',
#  '% Change',
#  'Volume',
#  'Market Cap',
#  'Intraday High/Low',
#  '52 Week Range',
#  'Day Chart']

# %%
print(table_head_fm )
# Out:
# ['Symbol', 'Name', 'Last Price', 'Market Time', 'Change', '% Change', 'Volume', 'Market Cap', 'Intraday High/Low', '52 Week Range', 'Day Chart']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = table_head_fm )
df
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, Last Price, Market Time, Change, % Change, Volume, Market Cap, Intraday High/Low, 52 Week Range, Day Chart]
# Index: []
